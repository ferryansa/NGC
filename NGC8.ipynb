# %% [markdown]
# # BAB 1 : PERKENALAN

# %%
'''
NGC 8
Nama: Ferryansa
Kelas: HCK-022
Objective: xxxx
'''

# %% [markdown]
# # BAB 2 : IMPORT PANDAS

# %%
import pandas as pd

# %% [markdown]
# # BAB 3 : DATA LOADING

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/data_ngc.csv')

df
# Out:
#       province_state country_region        date  latitude  longitude  \
# 0                NaN       Malaysia  2020-03-08    2.5000   112.5000
# 1                NaN       Malaysia  2020-03-10    2.5000   112.5000
# 2                NaN      Singapore  2020-03-13    1.3521   103.8198
# 3                NaN       Malaysia  2020-03-13    4.2105   101.9758
# 4                NaN       Malaysia  2020-03-15    4.2105   101.9758
# ...              ...            ...         ...       ...        ...
# 11925         Pahang       Malaysia  2022-06-02    3.8126   103.3256
# 11926         Pahang       Malaysia  2022-04-29    3.8126   103.3256
# 11927         Pahang       Malaysia  2022-01-10    3.8126   103.3256
# 11928         Pahang       Malaysia  2023-02-25    3.8126   103.3256
# 11929         Pahang       Malaysia  2022-09-29    3.8126   103.3256
#
#                 location_geom  confirmed  deaths  recovered  active  fips  \
# ...

# %% [markdown]
# # BAB 4 : DATA EXPLORATION

# %%
# melihat info table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11930 entries, 0 to 11929
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   province_state  9078 non-null   object
#  1   country_region  11930 non-null  object
#  2   date            11930 non-null  object
#  3   latitude        11321 non-null  float64
#  4   longitude       11321 non-null  float64
#  5   location_geom   11321 non-null  object
#  6   confirmed       11929 non-null  float64
#  7   deaths          11913 non-null  float64
#  8   recovered       1640 non-null   float64
#  9   active          1520 non-null   float64
#  10  fips            0 non-null      float64
#  11  admin2          0 non-null      float64
#  12  combined_key    11793 non-null  object
# dtypes: float64(8), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# insight: xxx penjelasan mengenai hasil xxx
#
# Berikutnya saya akan melihat terkait missing value pada dataframe berikut
#
# ##### tambahkan narasi agar antar step sebelumnya dan next step yang mau dilakukan akan saling berkaitan

# %%
df.isnull().sum()
# Out:
# province_state     2852
# country_region        0
# date                  0
# latitude            609
# longitude           609
# location_geom       609
# confirmed             1
# deaths               17
# recovered         10290
# active            10410
# fips              11930
# admin2            11930
# combined_key        137
# dtype: int64

# %% [markdown]
# recap explorasi:
# - explore sedalam mungkin terait dataframe
# - bisa dari ambil sample
# - bisa summary info
# - cek missing value
# - cek duplicate
# - cek beberpaa kolom yang tidak konsisten / tidak sesuai requirement

# %% [markdown]
# # BAB 5 : DATA CLEANING

# %% [markdown]
# ## Add new data

# %%
# ref : http://xxx

# ini dictionary untuk new data
new_row = {'country_region':'Malaysia'}

# insert new data
df.loc[len(df)] = new_row

# %%
# melihat hasil data yang baru dimasukan
df.tail(1)
# Out:
#       province_state country_region date  latitude  longitude location_geom  \
# 11930            NaN       Malaysia  NaN       NaN        NaN           NaN
#
#        confirmed  deaths  recovered  active  fips  admin2 combined_key
# 11930        NaN     NaN        NaN     NaN   NaN     NaN          NaN

# %% [markdown]
# ## Handling missing value
#
# untuk .drop() bisa 2 cara:
# - buat variable baru untuk menampung hasil drop
# - atau gunakan parameter `inplace=True` untuk menyimpan hasil drop ke dataframe existing

# %%
# brop column yang memiliki missing value
df.drop('combined_key', axis=1, inplace=True)

# %%
df
# Out:
#       province_state country_region        date  latitude  longitude  \
# 0                NaN       Malaysia  2020-03-08    2.5000   112.5000
# 1                NaN       Malaysia  2020-03-10    2.5000   112.5000
# 2                NaN      Singapore  2020-03-13    1.3521   103.8198
# 3                NaN       Malaysia  2020-03-13    4.2105   101.9758
# 4                NaN       Malaysia  2020-03-15    4.2105   101.9758
# ...              ...            ...         ...       ...        ...
# 11926         Pahang       Malaysia  2022-04-29    3.8126   103.3256
# 11927         Pahang       Malaysia  2022-01-10    3.8126   103.3256
# 11928         Pahang       Malaysia  2023-02-25    3.8126   103.3256
# 11929         Pahang       Malaysia  2022-09-29    3.8126   103.3256
# 11930            NaN       Malaysia         NaN       NaN        NaN
#
#                 location_geom  confirmed  deaths  recovered  active  fips  \
# ...

# %%
# imputation
df['recovered'].fillna(0.0)

# %% [markdown]
# # BAB 6 : DATA ANALISIS (SKIP DULU)
#
# melakukan analisis data menggunakan metode statistik dan data visualization (di week 3)

# %% [markdown]
# ## Kesimpulan
#
# rangkuman dari seluruh hasil yang ditemukan
