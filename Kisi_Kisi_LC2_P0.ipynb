# %% [markdown]
# # **Kisi-kisi LC2**
#
# Dataset yang digunakan pada latihan ini berasal dari bigquery public data. Lakukan koneksi Google Colaboratory dengan BigQuery menggunakan syntax berikut:
#
# ```
# from google.colab import auth
# from google.cloud import bigquery
# auth.authenticate_user()
# print('Authenticated')
#
# project_id = "hckv8-95102" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
# client = bigquery.Client(project=project_id)
# ```
#
# lalu lakukan query pada notebook menggunakan cara berikut:
#
# ```
# df_1 = client.query('''
# SELECT *
# FROM table_name`
# ''').to_dataframe()
#
# df_1
# ```
#
# ---
#
# Dataset yang digunakan merupakan `record perjalanan peminjam sepeda`, dapat diakses pada:
#
# - **Project_id_Database**: ftds-hacktiv8-project
# - **Dataset**            : practice
# - **Table**              : bike_rent
#
# Lakukan pengolahan SQL langsung melalui Google Colaboratory yang telah dikoneksikan pada BigQuery
#
# ---
# Pada notebook ini terdapat 2 section, **SQL** dan **Pandas**.
#
# Kerjakan masing-masing section sesuai dengan ketentuan di bawah:
#
# ## A. **SQL**
#
#   >**Jawab masing-masing soal dalam 1 query.**
#
#   1. Berapa banyak label unique dari `bike_type`?
#   2. Apa saja nama label unique dari tipe sepeda?
#   3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?
#   4. Dimana station yang paling banyak dikunjungi sebagai titik keberangkatan pada tahun 2016?
#   5. Berapa nilai minimum, maximum, dan rata-rata dari durasi perjalanan pada keseluruhan data?
#   6. Berapa rata-rata durasi perjalanan dari subscriber_type `Explorer` dan `Weekender`?
#   7. Tampilkan entry data yang memiliki `duration_time` diatas 4.25 jam. (*Gunakan subquery untuk menjawab pertanyaan ini dengan meng-convert duration_time dari menit ke hour*).
#
# ## B. **Pandas**
#   >**Data yang akan diolah menggunakan Pandas wajib diambil menggunakan Query berikut:**
#   ```
#   SELECT *
#   FROM `ftds-hacktiv8-project.practice.bike_rent`
#   ```
#
#   >Simpan data yang telah diambil ke dalam variabel `df` (penamaan variabel dibebaskan), **lakukan pengolah di bawah ini menggunakan library Pandas**:
#
#   1. Cek kesesuaian tipe data dan keberadaan missing values dengan `.info()`
#
#   2. Buat kolom baru bernama `quarter`.
#
#   Lakukan ekstraksi waktu (quarter dalam tahun) berdasarkan kolom `start_time` dengan ketentuan berikut:
#
# <div align="center">
#
#   |Keterangan Waktu|Bulan|
#   |--|--|
#   |Q1|Januari, Februari, Maret|
#   |Q2|April, Mei, Juni|
#   |Q3|Juli, Agustus, September|
#   |Q4|Oktober, November, Desember|
#
# </div>
#
#   3. Tampilkan data perjalanan dari tipe member `Local365` dengan durasi perjalanan diatas 1 jam *`(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)`*.
#
#   4. Berapa rata-rata durasi perjalanan dari tipe pelanggan `Walk Up` dengan tipe sepeda `classic` pada bulan `Maret` berdasarkan data yang diambil? *`(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)`*.
#
# >**Notes:**
# >- Dalam menjawab soal Pandas no. 2, **tidak boleh** menggunakan ekstraksi waktu `Series.dt.quarter`
# - Lakukan `looping` dan `conditional` dengan memanfaatkan ekstraksi bulan `Series.dt.month` terhadap kolom `start_time`, pastikan tipe datanya ialah `datetime` agar dapat dilakukan ekstraksi.
# - Simpan hasil looping ke dalam suatu variabel, dan buat kolom baru berisikan variabel sebelumnya.

# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
print('Authenticated')

project_id = "hacktiv8-022" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
client = bigquery.Client(project=project_id)
# Out:
# Authenticated

# %% [markdown]
# ###**SQL**

# %% [markdown]
# #####1. Berapa banyak label unique dari bike_type?

# %%
# working area
df_1 = client.query('''
SELECT
  COUNT(DISTINCT bike_type) AS uniqueLable_bike_type
FROM ftds-hacktiv8-project.practice.bike_rent;
''').to_dataframe()

df_1
# Out:
#    uniqueLable_bike_type
# 0                      2

# %% [markdown]
# #####2. Apa saja nama label unique dari tipe sepeda?

# %%
# working area
df_2 = client.query('''
SELECT
  DISTINCT bike_type
FROM ftds-hacktiv8-project.practice.bike_rent;
''').to_dataframe()

df_2
# Out:
#   bike_type
# 0   classic
# 1  electric

# %% [markdown]
# #####3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?

# %%
# working area
df_3 = client.query('''
SELECT
  EXTRACT(year FROM start_time) AS year,
  COUNT(*) AS total_rentals
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(year FROM start_time) IN (2016, 2017)
GROUP BY year;
''').to_dataframe()

df_3
# Out:
#    year  total_rentals
# 0  2017           4539
# 1  2016           3454

# %% [markdown]
# #####4. Dimana station yang paling banyak dikunjungi sebagai titik keberangkatan pada tahun 2016?

# %%
# working area
df_4 = client.query('''
SELECT
  start_station_name,
  COUNT(*) AS departure_count
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(year FROM start_time) = 2016
GROUP BY start_station_name
ORDER BY departure_count DESC
LIMIT 1;
''').to_dataframe()

df_4
# Out:
#                 start_station_name  departure_count
# 0  Bullock Museum @ Congress & MLK              394

# %% [markdown]
# #####5. Berapa nilai minimum, maximum, dan rata-rata dari durasi perjalanan pada keseluruhan data?

# %%
# working area
df_5 = client.query('''
SELECT
    MIN(duration_minutes) AS min_duration,
    MAX(duration_minutes) AS max_duration,
    AVG(duration_minutes) AS avg_duration
FROM ftds-hacktiv8-project.practice.bike_rent;
''').to_dataframe()

df_5
# Out:
#    min_duration  max_duration  avg_duration
# 0             2          2218       35.0995

# %% [markdown]
# #####6. Berapa rata-rata durasi perjalanan dari subscriber_type `Student Membership` dan `Local31`?

# %%
# working area
df_6 = client.query('''
SELECT
  subscriber_type,
  AVG(duration_minutes) AS average_duration
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE subscriber_type LIKE '%Student Membership%' OR subscriber_type LIKE '%Local30%'
GROUP BY subscriber_type;
''').to_dataframe()

df_6
# Out:
#            subscriber_type  average_duration
# 0                  Local30         16.021672
# 1  U.T. Student Membership         39.000000

# %% [markdown]
# #####7. Tampilkan entry data yang memiliki `duration_time` diatas 4.25 jam. (*Gunakan subquery untuk menjawab pertanyaan ini dengan meng-convert duration_time dari menit ke hour*).

# %%
# working area
df_7 = client.query('''
SELECT *
FROM (
    SELECT (duration_minutes/60) AS duration_hours
    FROM ftds-hacktiv8-project.practice.bike_rent
) AS subquery
WHERE duration_hours > 4.25;
''').to_dataframe()

df_7
# Out:
#     duration_hours
# 0         5.850000
# 1         5.833333
# 2        13.050000
# 3        13.150000
# 4         5.416667
# ..             ...
# 86        5.833333
# 87       10.716667
# 88       11.400000
# 89        4.866667
# 90       12.616667
#
# [91 rows x 1 columns]

# %% [markdown]
# ###**Pandas**

# %% [markdown]
# #####Data Loading

# %%
# working area
df = client.query('''
 SELECT *
 FROM `ftds-hacktiv8-project.practice.bike_rent`

 ''').to_dataframe()

df
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
# [8000 rows x 8 columns]

# %% [markdown]
# #####1. Cek kesesuaian tipe data dan keberadaan missing values dengan `.info()`

# %%
# working area
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   trip_id             8000 non-null   Int64
#  1   subscriber_type     8000 non-null   object
#  2   bike_id             8000 non-null   object
#  3   bike_type           8000 non-null   object
#  4   start_time          8000 non-null   datetime64[us, UTC]
#  5   start_station_name  8000 non-null   object
#  6   end_station_name    8000 non-null   object
#  7   duration_minutes    8000 non-null   Int64
# dtypes: Int64(2), datetime64[us, UTC](1), object(5)
# memory usage: 515.8+ KB

# %%
df.isnull().sum()
# Out:
# trip_id               0
# subscriber_type       0
# bike_id               0
# bike_type             0
# start_time            0
# start_station_name    0
# end_station_name      0
# duration_minutes      0
# dtype: int64

# %%
df['bike_id'] = pd.to_numeric(df['bike_id'], errors='coerce').astype('Int64')

# %%
df.dtypes
# Out:
# trip_id                             Int64
# subscriber_type                    object
# bike_id                             Int64
# bike_type                          object
# start_time            datetime64[us, UTC]
# start_station_name                 object
# end_station_name                   object
# duration_minutes                    Int64
# dtype: object

# %% [markdown]
# #####2. Buat kolom baru bernama `quarter`.
#
#   Lakukan ekstraksi waktu (quarter dalam tahun) berdasarkan kolom `start_time` dengan ketentuan berikut:
#
# <div align="center">
#
#   |Keterangan Waktu|Bulan|
#   |--|--|
#   |Q1|Januari, Februari, Maret|
#   |Q2|April, Mei, Juni|
#   |Q3|Juli, Agustus, September|
#   |Q4|Oktober, November, Desember|
#
# </div>
#
# >**Notes:**
# >- Dalam menjawab soal Pandas no. 2, **tidak boleh** menggunakan ekstraksi waktu `Series.dt.quarter`.
# - Lakukan `looping` dan `conditional` dengan memanfaatkan ekstraksi bulan `Series.dt.month` terhadap kolom `start_time`, pastikan tipe datanya ialah `datetime` agar dapat dilakukan ekstraksi.
# - Simpan hasil looping ke dalam suatu variabel, dan buat kolom baru berisikan variabel sebelumnya.

# %%
# working area
df['start_time'] = pd.to_datetime(df['start_time'])

quarter_list = []

for month in df['start_time'].dt.month:
    if month in [1, 2, 3]:
        quarter_list.append('Q1')
    elif month in [4, 5, 6]:
        quarter_list.append('Q2')
    elif month in [7, 8, 9]:
        quarter_list.append('Q3')
    elif month in [10, 11, 12]:
        quarter_list.append('Q4')

df['quarter'] = quarter_list
df
# Out:
#        trip_id subscriber_type  bike_id bike_type                start_time  \
# 0     18896589        Explorer       93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365      315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365      877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up      273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up      201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...      ...       ...                       ...
# 7995  15469480         Walk Up      327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up      528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up      235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up      206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up      315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes  is_filtered  \
# 0                              11th & Salina                178        False
# 1                                 Main Office               198        False
# 2                                 Main Office                60        False
# 3                                 Main Office                60        False
# 4                                 Main Office                60        False
# ...                                       ...               ...          ...
# 7995          Bullock Museum @ Congress & MLK                55        False
# 7996          Bullock Museum @ Congress & MLK                55        False
# 7997          State Capitol @ 14th & Colorado                55        False
# 7998          State Capitol @ 14th & Colorado                55        False
# 7999  Capital Metro HQ - East 5th at Broadway                55        False
#
#      quarter
# 0         Q4
# 1         Q1
# 2         Q4
# 3         Q4
# 4         Q4
# ...      ...
# 7995      Q3
# 7996      Q4
# 7997      Q1
# 7998      Q2
# 7999      Q2
#
# [8000 rows x 10 columns]

# %% [markdown]
# #####3. Tampilkan data perjalanan dari tipe member `Local31` dengan durasi perjalanan diatas 1 jam.
# *(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)*

# %%
# working area
df['is_filtered'] = (df['subscriber_type'] == 'Local30') & (df['duration_minutes'] > 60)

df[df['is_filtered']]
# Out:
#        trip_id subscriber_type  bike_id bike_type                start_time  \
# 24    13903148         Local30       62   classic 2017-03-02 17:26:17+00:00
# 39    11900970         Local30      666   classic 2016-09-13 12:19:41+00:00
# 42    11918705         Local30      200   classic 2016-09-14 12:33:27+00:00
# 47    12111057         Local30      930   classic 2016-09-27 11:54:40+00:00
# 56    12563092         Local30      464   classic 2016-10-26 11:54:07+00:00
# 64    12458429         Local30      513   classic 2016-10-19 12:16:29+00:00
# 149   14638999         Local30      432   classic 2017-05-01 07:23:30+00:00
# 157   15065592         Local30       88   classic 2017-06-08 16:02:58+00:00
# 201   13526115         Local30      277   classic 2017-01-24 07:27:33+00:00
# 263   14729536         Local30      114   classic 2017-05-08 15:45:34+00:00
# 343   12065614         Local30      452   classic 2016-09-23 23:00:11+00:00
# 374   15865752         Local30      198   classic 2017-09-05 17:14:36+00:00
# 440   14968922         Local30      875   classic 2017-05-29 14:13:44+00:00
# 670   12523096         Local30      589   classic 2016-10-23 18:55:47+00:00
# 683   14766785         Local30      881   classic 2017-05-11 21:01:13+00:00
# 808   16404425         Local30      156   classic 2017-11-19 16:17:14+00:00
# 813   16457909         Local30      414   classic 2017-11-30 20:09:15+00:00
# 1188   9690519         Local30      105   classic 2016-04-23 16:32:30+00:00
#
#                    start_station_name  \
# 24                         Pease Park
# 39                       Lavaca & 6th
# 42                       Lavaca & 6th
# 47                       Lavaca & 6th
# 56                       Lavaca & 6th
# 64                       Lavaca & 6th
# 149            Davis at Rainey Street
# 157            Davis at Rainey Street
# 201            Davis at Rainey Street
# 263   Bullock Museum @ Congress & MLK
# 343                11th & San Jacinto
# 374                11th & San Jacinto
# 440   State Capitol @ 14th & Colorado
# 670     Pfluger Bridge @ W 2nd Street
# 683                 Palmer Auditorium
# 808    East 11th St. at Victory Grill
# 813    East 11th St. at Victory Grill
# 1188                 5th & San Marcos
#
#                              end_station_name  duration_minutes  is_filtered  \
# 24                                 Pease Park                90         True
# 39                               Lavaca & 6th                73         True
# 42                               Lavaca & 6th                66         True
# 47                               Lavaca & 6th                71         True
# 56                               Lavaca & 6th                62         True
# 64                               Lavaca & 6th                75         True
# 149                              Lavaca & 6th               137         True
# 157                              Lavaca & 6th               174         True
# 201                           Guadalupe & 6th               138         True
# 263                          17th & Guadalupe               497         True
# 343                        11th & San Jacinto                71         True
# 374                        11th & San Jacinto               409         True
# 440                        13th & San Antonio               106         True
# 670                Barton Springs & Riverside               308         True
# 683                Barton Springs & Riverside               182         True
# 808            East 11th St. at Victory Grill               112         True
# 813            East 11th St. at Victory Grill               190         True
# 1188  Capital Metro HQ - East 5th at Broadway               146         True
#
#      quarter
# 24        Q1
# 39        Q3
# 42        Q3
# 47        Q3
# 56        Q4
# 64        Q4
# 149       Q2
# 157       Q2
# 201       Q1
# 263       Q2
# 343       Q3
# 374       Q3
# 440       Q2
# 670       Q4
# 683       Q2
# 808       Q4
# 813       Q4
# 1188      Q2

# %% [markdown]
# #####4. Berapa rata-rata durasi perjalanan dari tipe pelanggan `Walk Up` dengan tipe sepeda `classic` pada bulan `Maret` dari data yang diambil?
# *(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)*

# %%
# working area
march_data = df[(df['subscriber_type'] == 'Walk Up') &
                (df['bike_type'] == 'classic') &
                (df['start_time'].dt.month == 3)]

march_data['duration_minutes'].mean()
# Out:
# 38.476584022038566

# %%
df_1.to_csv('a_out.csv')
